# %%
# !pip install requirements.txt
# Out:
# Collecting requirements.txt
#   Could not find a version that satisfies the requirement requirements.txt (from versions: )
# No matching distribution found for requirements.txt

# %%
import xml.etree.ElementTree as ET
import pandas as pd
import csv

# %% [markdown]
# ## Downlading and parsing XML file with ETree

# %%
### step 2: parse XML and get root
url = '../BoojCodeTest.xml'
tree = ET.parse(url)
root = tree.getroot()


# root = ET.parse(url).getroot()
# root = tree

# %%
### step 3 : create and open CSV
xml_data_to_csv = open('output.csv', 'w')

# %%
### step 4 : create list to contain header
list_head = []

# %%
### step 5 : create variable to write to csv
csv_writer = csv.writer(xml_data_to_csv)

# %%
### step 6 : loop for each node
count = 0
for element in root.findall('Listing'):
    List_nodes = []

    #Get head by tag
    if count == 0:    
    
        for location in element.findall('Location'):
            StreetAddress = location.find('StreetAddress').tag
            list_head.append(StreetAddress)
    

        
        for listingdetail in element.findall('ListingDetails'):
            
            MlsId = listingdetail.find('MlsId').tag
            list_head.append(MlsId)
        
            MlsName = listingdetail.find('MlsName').tag
            list_head.append(MlsName)
        
            DateListed = listingdetail.find('DateListed').tag
            list_head.append(DateListed)
                           
            Price  = listingdetail.find('Price').tag
            list_head.append(Price)
        
            
            
        for basicdetail in element.findall('BasicDetails'):
            
            Description = basicdetail.find('Description').tag
            list_head.append(Description)            

            Bedrooms  = basicdetail.find('Bedrooms').tag
            list_head.append(Bedrooms)
        
            Bathrooms  = basicdetail.find('FullBathrooms').tag
            list_head.append(Bathrooms)
            

        for richdetail in element.findall('RichDetails'):

            Appliances  = richdetail.find('Appliances').tag
            list_head.append(Appliances)
        
            Rooms = richdetail.find('RoomCount').tag
            list_head.append(Rooms)

        
        csv_writer.writerow(list_head)
        count += 1
       
    #get child node
    for location in element.findall('Location'):
            
        StreetAddress = location.find('StreetAddress').text
        List_nodes.append(StreetAddress)
    

        
    for listingdetail in element.findall('ListingDetails'):
            
        MlsId = listingdetail.find('MlsId').text
        List_nodes.append(MlsId)
        
        MlsName = listingdetail.find('MlsName').text
        List_nodes.append(MlsName)
        
        DateListed = listingdetail.find('DateListed').text
        List_nodes.append(DateListed)
                           
        Price  = listingdetail.find('Price').text
        List_nodes.append(Price)
        
            
            
    for basicdetail in element.findall('BasicDetails'):
            
        Description = basicdetail.find('Description').text
        List_nodes.append(Description[:200])            

        Bedrooms  = basicdetail.find('Bedrooms').text
        List_nodes.append(Bedrooms)
        
        Bathrooms  = basicdetail.find('FullBathrooms').text
        List_nodes.append(Bathrooms)
            
    
    for richdetail in element.findall('RichDetails/Appliances'):

        Appliances  = richdetail.findtext('Appliance')
        List_nodes.append(Appliances)
        
    for richdetail in element.findall('RichDetails/Rooms'):
        
        Rooms = richdetail.findtext('Room')
        List_nodes.append(Rooms)    
    
    
    
#     for richdetail in element.findall('RichDetails'):

#         Appliances  = richdetail.findtext('Appliance')
#         List_nodes.append(Appliances)
        
#         Rooms = richdetail.findtext('Room')
#         List_nodes.append(Rooms)
    
    csv_writer.writerow(List_nodes)
    
#close csv file
xml_data_to_csv.close()

# %% [markdown]
# # ***must go one layer deeper for appliances and Rooms, separate with ','***

# %% [markdown]
# ## Creating a DataFrame

# %%
with open('output.csv', 'rb') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    master = list(reader)
    
print(master[:5])
# Out:
# [['StreetAddress', 'MlsId', 'MlsName', 'DateListed', 'Price', 'Description', 'Bedrooms', 'FullBathrooms', 'Appliances', 'RoomCount'], ['0 Castro Peak Mountainway', '14799273', 'CLAW', '2014-10-03 00:00:00', '535000.00', 'Enjoy amazing ocean and island views from this 10+ acre parcel situated in a convenient and peaceful area of the Santa Monica mountains. Just minutes from beaches or the 101, Castro Peak is located of', '0', '', ''], ['0 SADDLE PEAK RD', '14802845', 'CLAW', '2014-10-17 00:00:00', '200000.00', 'Spectacular views from this 4+ acre property perched on the ridge between PCH and the Valley. Two APNs - 4438-034-037 and 031 being sold together. Plus, there is a lot next door for sale too! A, paved', '0', '', ''], ['21310 PACIFIC COAST HWY', '15883387', 'CLAW', '2015-03-03 00:00:00', '23500.00', 'A STUNNING Architectural beautifully designed with pillowed stone floors, hand rubbed Venetian plaster walls, 11 ft ceilings filled with natural light, theatrical mood lighting, 3 fireplaces, two huge', '3', '4', 'Built-Ins', 'bedrooms'], ['23826 MALIBU RD', '15888095', 'CLAW', '2015-03-18 00:00:00', '72500.00', 'July & August not available. "Captured in Paradise." Arguably on the most desired sandy beach of Malibu, this home-away-from-home offers a sophisticated zen ambiance & elegance at the beach. This priv', '5', '4', 'Built-Ins', 'bedrooms']]

# %%
header = master[0]
data = master[1:]

# %%
data[20]
# Out:
# ['2401 Laurel Canyon Boulevard',
#  '16134704',
#  'CLAW',
#  '2016-06-14 00:00:00',
#  '1298000.00',
#  'COMPOUND OPPORTUNITY HIDDEN IN PLAIN SIGHT.10 contiguous VACANT LOTS ONLY, (there is NO house) currently on this property totaling approx: 2.5 acres which includes an APPROX: 18,000 SF flat pad. Once ',
#  '0',
#  '',
#  '']

# %%
data
# Out:
# [['0 Castro Peak Mountainway',
#   '14799273',
#   'CLAW',
#   '2014-10-03 00:00:00',
#   '535000.00',
#   'Enjoy amazing ocean and island views from this 10+ acre parcel situated in a convenient and peaceful area of the Santa Monica mountains. Just minutes from beaches or the 101, Castro Peak is located of',
#   '0',
#   '',
#   ''],
#  ['0 SADDLE PEAK RD',
#   '14802845',
#   'CLAW',
#   '2014-10-17 00:00:00',
#   '200000.00',
#   'Spectacular views from this 4+ acre property perched on the ridge between PCH and the Valley. Two APNs - 4438-034-037 and 031 being sold together. Plus, there is a lot next door for sale too! A, paved',
#   '0',
#   '',
#   ''],
#  ['21310 PACIFIC COAST HWY',
#   '15883387',
#   'CLAW',
#   '2015-03-03 00:00:00',
#   '23500.00',
#   'A STUNNING Architectural beautifully designed with pillowed stone floors, hand rubbed Venetian plaster walls, 11 ft ceilings filled with natural light, theatrical mood lighting, 3 fireplaces, two huge',
#   '3',
#   '4',
#   'Built-Ins',
#   'bedrooms'],
#  ['23826 MALIBU RD',
#   '15888095',
#   'CLAW',
#   '2015-03-18 00:00:00',
#   '72500.00',
#   'July & August not available. "Captured in Paradise." Arguably on the most desired sandy beach of Malibu, this home-away-from-home offers a sophisticated zen ambiance & elegance at the beach. This priv',
#   '5',
#   '4',
#   'Built-Ins',
#   'bedrooms'],
#  ['943 16th ST',
#   '15959941',
#   'CLAW',
#   '2015-11-18 00:00:00',
#   '230000.00',
#   'Due to an overwhelming response we are no longer accepting applicants for this unit. We have an extensive list of candidates & new inquiries will not be returned. This unit is being strictly sold as r',
#   '2',
#   '1',
#   'RangeOven',
#   'bedrooms'],
#  ['27061 SEA VISTA DR',
#   '15965091',
#   'CLAW',
#   '2015-12-11 00:00:00',
#   '2988000.00',
#   'Beautiful ocean and coastline views from this private lot situated off of PCH. Amazing views of the Point Dume cliffs with the opportunity to enjoy incredible sunsets without a long drive up a canyon.',
#   '0',
#   '',
#   ''],
#  ['27086 MALIBU COVE COLONY DR',
#   '16106762',
#   'CLAW',
#   '2016-03-16 00:00:00',
#   '25000.00',
#   'Gorgeous oceanfront home with views to Point Dume and direct beach access. This beach house is ideal for entertaining with a kitchen open to a great room and ocean front deck. Possible fourth bedroom ',
#   '3',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['36 BREEZE AVE',
#   '16109128',
#   'CLAW',
#   '2016-03-25 00:00:00',
#   '6500.00',
#   'his designer, custom architectural remodel on the charming Breeze walk-street is the epitome of luxurious and efficient living. Walls of warm reclaimed wood line the architectural interior, while expa',
#   '2',
#   '1',
#   'Built-Ins',
#   'bedrooms'],
#  ['31652 BROAD BEACH RD',
#   '16114818',
#   'CLAW',
#   '2016-04-12 00:00:00',
#   '5800000.00',
#   'Welcome to an oasis over looking the Pacific Ocean, where crashing waves and vivid sunsets create the quintessential Beach living environment. The controlled access exterior entry sets the tone for th',
#   '3',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['1912 KELTON AVE',
#   '16115130',
#   'CLAW',
#   '2016-04-13 00:00:00',
#   '5499.00',
#   'Beautiful traditional Spanish in the heart of Westwood! Charming original details include high, vaulted ceilings in living room, cozy wood-burning fireplace, arched doorways, shelving alcoves, painted',
#   '3',
#   '2',
#   '',
#   'bedrooms'],
#  ['11258 Laurie Drive',
#   '16115640',
#   'CLAW',
#   '2016-04-14 00:00:00',
#   '798000.00',
#   'NEW PROJECT - SHOVEL READY. *NOTE* This project has Ready To Issue (RTI) PERMITS because the Design Review Board has approved this development, for the Mulholland Scenic Parkway Corridor, in addition ',
#   '0',
#   '',
#   ''],
#  ['28011 PAQUET PL',
#   '16118008',
#   'CLAW',
#   '2016-04-25 00:00:00',
#   '6995000.00',
#   'Beautiful estate with panoramic ocean views located in the gated community of Ramirez Canyon. This 5 bed, 5 bath features an open floor plan with natural light and stunning ocean & mountain views thro',
#   '5',
#   '4',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['6237 BONSALL DR',
#   '16122648',
#   'CLAW',
#   '2016-05-06 00:00:00',
#   '6649000.00',
#   'A prime flat ~1.5 acre lot w/ a unique use of modern finishes & innovative design by Vitus Matare. This private gated single story marvel is adorned w/ mature trees ranging from avocados to evergreens',
#   '3',
#   '3',
#   '',
#   'bedrooms'],
#  ['0 BROAD BEACH RD',
#   '16125100',
#   'CLAW',
#   '2016-05-16 00:00:00',
#   '150000.00',
#   "Unlike any other luxury opportunity, this beautiful Malibu compound offers a flat acre w/ over 120' of beach frontage; a lot depth extending 400'! A gated entrance, simple yet dignified, opens to a 2-",
#   '6',
#   '7',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['31341 BIRDELLA RD',
#   '16129206',
#   'CLAW',
#   '2016-05-26 00:00:00',
#   '5975.00',
#   'Nestled in the heart of the Santa Monica Mountains, this serene setting invites you to hike, climb, or horseback ride throughout the day, then relax to the sounds of nature narrating the clear stellar',
#   '4',
#   '2',
#   '',
#   'bedrooms'],
#  ['32036 PACIFIC COAST HWY',
#   '16130744',
#   'CLAW',
#   '2016-06-02 00:00:00',
#   '2450000.00',
#   'Build your Malibu dream home! Flat lot on almost one-half acre with pristine ocean views on the ocean side of PCH. Gated and private building site including deeded beach rights to one of the most beau',
#   '0',
#   '',
#   ''],
#  ['888 Blackmore DR',
#   '16132084',
#   'CLAW',
#   '2016-06-05 00:00:00',
#   '2888000.00',
#   'This approx: 59 ACRE DEVELOPMENT SITE consists of SIX vacant lots. These lots sit on the back and the front side of a hill with a fire road running across the top part of the hill. The largest lot whi',
#   '0',
#   '',
#   ''],
#  ['19252 PACIFIC COAST HWY',
#   '16132158',
#   'CLAW',
#   '2016-06-06 00:00:00',
#   '27500.00',
#   "Rare 98ft Ocean Front Classic Beauty reminiscent of glamorous days from a bygone era. Magnanimous rms paneled & floored w/ rain forest woods ooze casual elegance ala the Titanic. From the street you'l",
#   '3',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1970 N GRAMERCY PL',
#   '16133142',
#   'CLAW',
#   '2016-07-15 00:00:00',
#   '1699000.00',
#   'Tranquility awaits at this 1935 Traditional hillside retreat in the coveted Los Feliz Oaks. Tucked away in a quiet cul-de-sac, this home boasts a dramatic living room with beamed ceilings, a decorativ',
#   '3',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['9229 Crescent Drive',
#   '16134056',
#   'CLAW',
#   '2016-06-11 00:00:00',
#   '1498000.00',
#   'High up in the Hollywood Hills, are 6 contiguous flat lots with Double Sided views, totaling approx: 17,400 SF. All 6 lots have superb views of both the City of Los Angeles AND Trousdale Estates. APN ',
#   '0',
#   '',
#   ''],
#  ['2401 Laurel Canyon Boulevard',
#   '16134704',
#   'CLAW',
#   '2016-06-14 00:00:00',
#   '1298000.00',
#   'COMPOUND OPPORTUNITY HIDDEN IN PLAIN SIGHT.10 contiguous VACANT LOTS ONLY, (there is NO house) currently on this property totaling approx: 2.5 acres which includes an APPROX: 18,000 SF flat pad. Once ',
#   '0',
#   '',
#   ''],
#  ['24808 Woolsey Canyon RD',
#   '16134756',
#   'CLAW',
#   '2016-06-14 00:00:00',
#   '1298000.00',
#   'RESIDENTIAL DEVELOPMENT SITE: Consisting of 10 vacant lots on approx: 32 acres, with several BIG FLAT PADS and SWEEPING VALLEY VIEWS of San Fernando Valley, Warner Center and the Mountains. Reports ar',
#   '0',
#   '',
#   ''],
#  ['386 ENTRADA DR',
#   '16134906',
#   'CLAW',
#   '2016-06-16 00:00:00',
#   '1749000.00',
#   'Location, location, location! Charming Mediterranean style home in the highly desirable Santa Monica Canyon. This home is customized throughout with a gourmet cooks kitchen with imported Italian grani',
#   '2',
#   '2',
#   'Range Hood',
#   'bedrooms'],
#  ['7350 PACIFIC VIEW DR',
#   '16135516',
#   'CLAW',
#   '2016-06-16 00:00:00',
#   '2195000.00',
#   'Perched above a cul-de-sac in the Hollywood Hills, this Dramatic newly constructed home is of the highest quality. Steel, concrete and glass with a clean modern aesthetic and a bright inviting atmosph',
#   '3',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['3464 SWEETWATER MESA RD',
#   '16136820',
#   'CLAW',
#   '2016-07-06 00:00:00',
#   '17500000.00',
#   'NEWLY PRICED TO SELL! Iconic Malibu living abounds in this architectural oasis atop a generous 4.25 acres within the exclusive Serra Retreat. Recently updated by a celebrated designer, the home offers',
#   '5',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1422 SAN YSIDRO DR',
#   '16137056',
#   'CLAW',
#   '2016-06-22 00:00:00',
#   '2035000.00',
#   "Location,location,location. Located on one of BH's premier streets San Ysidro, this home is waiting for its next homeowner to put their magical touch on it. This home has 2 beds and 2 baths with an op",
#   '2',
#   '2',
#   'Range Hood',
#   'bedrooms'],
#  ['6225 GAYTON PL',
#   '16137086',
#   'CLAW',
#   '2016-06-24 00:00:00',
#   '3195000.00',
#   'This beautiful 4 bedroom/4.5 bath is situated on approximately 1 acre with phenomenal mountain views in a tranquil setting and located in a gated community. The home offers a gourmet kitchen with gran',
#   '4',
#   '4',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1116 LINDA FLORA DR',
#   '16141262',
#   'CLAW',
#   '2016-07-06 00:00:00',
#   '34999.00',
#   'Designed by renowned architect Walter Scott Perry in the classic modern Bauhaus tradition, this newly remodeled, 5 bedroom & 6 bathroom contemporary home is sited on a serene, half-acre knoll in Bel A',
#   '5',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['2317 Dickenson RD',
#   '16142180',
#   'CLAW',
#   '2016-07-11 00:00:00',
#   '20000000.00',
#   'An hour outside of Los Angles with country and ocean views of Ojai sits Flying D Ranch. The ultimate ranch - surrounded by a seasonal creek and expansive terrain. Consisting of 1,281 acres and 7 parce',
#   '3',
#   '2',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['514 LILLIAN WAY',
#   '16142204',
#   'CLAW',
#   '2016-07-21 00:00:00',
#   '1399000.00',
#   'MOTIVATED SELLER! BRING US AN OFFER!! Perfectly situated between the Wilshire Country Club and the Los Angeles Tennis Club, come see this charming Spanish 3-bedroom house with central air and incredib',
#   '3',
#   '1',
#   'Built-In Gas',
#   'bedrooms'],
#  ['2600 Canada Este RD',
#   '16144050',
#   'CLAW',
#   '2016-07-18 00:00:00',
#   '5495000.00',
#   "CENT'ANNI Estate is an alluring 20 acre property amidst the picturesque countryside of Santa Ynez in the secluded, idyllic setting of Los Olivos. This is a once in a lifetime opportunity to acquire a ",
#   '6',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['602 PALISADES BEACH RD',
#   '16145020',
#   'CLAW',
#   '2016-07-21 00:00:00',
#   '10500000.00',
#   "Incredible opportunity to own this classic French Revival sitting on over 11,000 square feet of beach front land right in the middle of Santa Monica's famed Gold Coast. With 59 feet of beachfront, it ",
#   '7',
#   '7',
#   '',
#   'bedrooms'],
#  ['4906 MENDOTA AVE',
#   '16146358',
#   'CLAW',
#   '2016-07-22 00:00:00',
#   '468300.00',
#   'Amazing investor opportunity in hot, hot Highland Park. This is a Probate sale that requires court confirmation. Cash buyers only. Executor asks that you do not walk on property. No open houses, no sh',
#   '2',
#   '1',
#   '',
#   'bedrooms'],
#  ['4017 E 6TH ST',
#   '16146576',
#   'CLAW',
#   '2016-07-22 00:00:00',
#   '336900.00',
#   'There is an accepted offer at $308,500. The court confirmation hearing for the Sale is currently set for November 15, 2016 at 8:30 a.m. in Dept. 11 of Los Angeles County Superior Court located at 111 ',
#   '2',
#   '1',
#   '',
#   'bedrooms'],
#  ['29220 WAGON RD',
#   '16148546',
#   'CLAW',
#   '2016-07-29 00:00:00',
#   '2688000.00',
#   'Perched atop a secluded promontory, this inspired contemporary compound is located within the exclusive gated community of Medea Valley Estates, optimally positioned between Malibu and Agoura Hills. O',
#   '6',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['29672 ZUMA BAY WAY',
#   '16150042',
#   'CLAW',
#   '2016-08-05 00:00:00',
#   '1900000.00',
#   'Impeccable townhome located in a 24-hour guard gated enclave known as Zuma Bay Villas. An amazing opportunity to call this your home, a turnkey investment, or a personal vacation escape with several p',
#   '3',
#   '1',
#   'Built-Ins',
#   'bedrooms'],
#  ['1961 DE MILLE DR',
#   '16150280',
#   'CLAW',
#   '2016-08-09 00:00:00',
#   '5540000.00',
#   'Beautiful architectural home with stunning 180 degree views from downtown to the ocean. This 6 bedroom 4.5 bath is tucked behind the highly desirable gates of the exclusive Laughlin Park Community. Th',
#   '6',
#   '4',
#   '',
#   'bedrooms'],
#  ['27112 MALIBU COVE COLONY DR',
#   '16150318',
#   'CLAW',
#   '2016-08-05 00:00:00',
#   '20000.00',
#   'This sleek and sexy beach house is located on a private guard-gated lane in the center of Malibu. Upon entry, the home immediately introduces you to the Pacific Ocean with a two story entry, walls of ',
#   '3',
#   '3',
#   'Range Hood',
#   'bedrooms'],
#  ['181 SURFVIEW DR',
#   '16150758',
#   'CLAW',
#   '2016-08-05 00:00:00',
#   '10815.00',
#   'Spectacular Contemporary with dramatic and architectural details. Exquisitely updated with fine attention to detail. Ocean view from most rooms, yard and decks. Gorgeous living/media room with bar are',
#   '4',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['4960 VANALDEN AVE',
#   '16151208',
#   'CLAW',
#   '2016-08-11 00:00:00',
#   '3495000.00',
#   'Designed by noted architect Gus Duffy and situated on approx 3/4\'s of an acre, this resort like estate defines the meaning of "compound". The Casa: Is a single story 4+3.5 home, beautiful in rich wood',
#   '7',
#   '4',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['19355 PACIFIC COAST HWY',
#   '16151674',
#   'CLAW',
#   '2016-08-10 00:00:00',
#   '3500.00',
#   "This charming, fully furnished 1 bedroom, 1 bath cottage sits on the grounds originally developed in the 1930's known as The Malibu Lodge. Truly a special property, across the street from Las Tunas St",
#   '1',
#   '1',
#   'RangeOven',
#   'bedrooms'],
#  ['7135 HOLLYWOOD',
#   '16153228',
#   'CLAW',
#   '2016-08-15 00:00:00',
#   '650000.00',
#   "Hollywood Versailles Towers at it's best! Come see this hip, designer perfect condo in the fabulous, full-service building on Hollywood Boulevard! Bring your toothbrush and move in! This condo has a f",
#   '1',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['9640 SIERRA HWY',
#   '16154748',
#   'CLAW',
#   '2016-08-22 00:00:00',
#   '12800000.00',
#   'Just 35 miles outside of Los Angeles, Agua Dulce Winery is a breathtaking 90-acre property affording oenophiles the rarity of owning a countryside estate featuring a spacious 5-bedroom residence and t',
#   '5',
#   '4',
#   'RangeOven',
#   'bedrooms'],
#  ['6420 SYCAMORE MEADOWS DR',
#   '16154856',
#   'CLAW',
#   '2016-08-30 00:00:00',
#   '10500.00',
#   'Modern Ranch Beach Bungalow in Sycamore Park. Located in idyllic Sycamore Park, steps from Escondido Beach, this light, airy, open home features vaulted whitewashed ceilings, hardwood floors, elegant ',
#   '4',
#   '2',
#   '',
#   'bedrooms'],
#  ['6410 SURFSIDE WAY',
#   '16154966',
#   'CLAW',
#   '2016-08-19 00:00:00',
#   '2288000.00',
#   "Located in one of Malibu's most desirable beachside neighborhoods, Malibu Park, this modern single-story home is styled with tranquil, Zen elements throughout. Close proximity to Zuma Beach, schools, ",
#   '3',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['24014 PARK CASINO',
#   '16155556',
#   'CLAW',
#   '2016-08-22 00:00:00',
#   '1719500.00',
#   'Gorgeous home with view of Calabasas golf course, Located in the sought after Las Virgenes School District. Nice and bright with an impressive entryway with skylights that opens into the living room o',
#   '4',
#   '3',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1100 N BEVERLY GLEN',
#   '16155592',
#   'CLAW',
#   '2016-08-22 00:00:00',
#   '5700.00',
#   'Stunning Contemporary in Beverly Glen. Centrally located near Bel Air, Beverly Hills, Westwood, and Century City. The home has been tastefully updated with top quality finishes. Features hardwood floo',
#   '3',
#   '2',
#   'Range Hood',
#   'bedrooms'],
#  ['1016 OAKWOOD AVE',
#   '16156574',
#   'CLAW',
#   '2016-08-26 00:00:00',
#   '1450000.00',
#   'AMAZING OPPORTUNITY IN VENICE! Charming beach cottage with 3 bedrooms and one bathroom in main house. Hardwood floors, light and bright, spacious bathroom and laundry inside. Legal back studio with st',
#   '3',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['5100 ANGELES VISTA BLVD',
#   '16157052',
#   'CLAW',
#   '2016-08-26 00:00:00',
#   '975000.00',
#   'Classic 1928 Spanish Casa located in the desirable View Park enclave, recently designated in the National Registry of Historic Places.',
#   '3',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['200 TOYOPA DR',
#   '16157428',
#   'CLAW',
#   '2016-08-29 00:00:00',
#   '20000000.00',
#   'Perched atop the coveted Huntington area of the Pacific Palisades, this oceanside manor is nothing short of presidential - a rare composition of remarkable stonework flush with ivy and backlit by the ',
#   '7',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['16242 SHADOW MOUNTAIN DR',
#   '16157766',
#   'CLAW',
#   '2016-09-02 00:00:00',
#   '10620000.00',
#   'Shadow Mountain is an enclave of 46 wonderful estates that enjoy 24 hour live-gated security just minutes from all that Pacific Palisades has to offer. This spectacular property was conceived and cust',
#   '8',
#   '8',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['22042 CARBON MESA RD',
#   '16157850',
#   'CLAW',
#   '2016-08-30 00:00:00',
#   '2995000.00',
#   "68 yrs ago the owners picked this spot overlooking the now famous Billionaires' Beach in Malibu. This pastoral sanctuary, approx. 2.8 acres, has panoramic Ocean Views from Santa Monica's shoreline to ",
#   '5',
#   '2',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['6420 SYCAMORE MEADOWS DR',
#   '16158240',
#   'CLAW',
#   '2016-08-31 00:00:00',
#   '3169000.00',
#   'Modern Ranch Beach Bungalow in idyllic Sycamore Park. Just steps from Escondido Beach, this light, airy, open home features vaulted whitewashed ceilings, hardwood floors, elegant lines & sophisticated',
#   '4',
#   '2',
#   '',
#   'bedrooms'],
#  ['3464 GREENWOOD AVE',
#   '16158556',
#   'CLAW',
#   '2016-09-06 00:00:00',
#   '1299000.00',
#   'Tropical Traditional on the Famed Mar Vista Wood Streets. A gated, grassy front yard welcomes you to 3 bed 2.5 bath home with a large office. Enjoy an updated kitchen with an oversized granite peninsu',
#   '3',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['10747 WILSHIRE',
#   '16158874',
#   'CLAW',
#   '2016-09-02 00:00:00',
#   '720000.00',
#   'Prime Wilshire corridor location! Secure building with a 24 hr. doorman. Light and bright luxury unit, the best bargain on the Wilshire corridor. 2 bdrm/ 2 bath updated condo with plantation shutters ',
#   '2',
#   '2',
#   'Microwave',
#   'bedrooms'],
#  ['11647 BELLAGIO RD',
#   '16159656',
#   'CLAW',
#   '2016-09-06 00:00:00',
#   '2400000.00',
#   "Located on one of Bel Air's most coveted streets, this superb property provides an escape from city life to a sanctuary of treetop vistas and glorious views of the Getty Museum and Catalina Island on ",
#   '7',
#   '5',
#   'Built-Ins',
#   'bedrooms'],
#  ['316 N SKYEWIAY RD',
#   '16159808',
#   'CLAW',
#   '2016-09-08 00:00:00',
#   '3995000.00',
#   'New Construction in the heart of Brentwood. This "East Coast Beach Cottage" influenced 5 bedroom, 5 bath home has a flexible open floorplan and works well for daily living and entertaining. The formal',
#   '5',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['545 CATALONIA AVE',
#   '16160058',
#   'CLAW',
#   '2016-09-09 00:00:00',
#   '2895000.00',
#   'An architectural wonder designed by renowned architect David Kellen, a student of Frank Israel and colleague of Frank Gehry, this neo-modern ranch is perched atop the rolling hills of Pacific Palisade',
#   '4',
#   '5',
#   'Built-Ins',
#   'bedrooms'],
#  ['868 LEONARD RD',
#   '16160314',
#   'CLAW',
#   '2016-09-08 00:00:00',
#   '5498000.00',
#   'Thoughtfully placed on an idyllic Brentwood cul-de-sac, this newly constructed California Modern was beautifully conceived by Marmol Radziner to blend effortlessly into the hillside topography by way ',
#   '5',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['21425 Rambla Vista',
#   '16161032',
#   'CLAW',
#   '2016-09-09 00:00:00',
#   '450000.00',
#   'This upslope lot in the desirable La Costa area of Malibu is located less than a minute off of PCH and is in close proximity to shopping, schools, and Santa Monica. Enjoy panoramic ocean and whitewate',
#   '0',
#   '',
#   ''],
#  ['7931 ZEUS DR',
#   '16161068',
#   'CLAW',
#   '2016-09-10 00:00:00',
#   '7900.00',
#   '4 bedroom + 3.5 bathrooms, 3162 sqft home with pool on a 12,219 sqft lot. Cul-de-sac location, convenient to Sunset Strip, Hollywood and West Hollywood. Spacious Modern Spanish home with city views an',
#   '4',
#   '3',
#   '',
#   'bedrooms'],
#  ['1900 PETERSON AVE',
#   '16161388',
#   'CLAW',
#   '2016-09-14 00:00:00',
#   '2588000.00',
#   'Extraordinary view home located in the award-winning South Pasadena School district. Located minutes to Downtown LA, USC and Caltech. This home showcases stunning views of downtown, mountains & trees.',
#   '6',
#   '3',
#   'Microwave',
#   'bedrooms'],
#  ['10700 ARTRUDE ST',
#   '16161666',
#   'CLAW',
#   '2016-09-16 00:00:00',
#   '969000.00',
#   'Located on a peaceful cul-de-sac in the lovely equestrian community of Shadow Hills, this extensively updated modern ranch home is the perfect turnkey opportunity. Upon entering this home, you are gre',
#   '4',
#   '2',
#   'Range Hood',
#   'bedrooms'],
#  ['10501 EASTBORNE AVE',
#   '16162304',
#   'CLAW',
#   '2016-09-15 00:00:00',
#   '3248000.00',
#   'This impressive modern construction sets the standard in this highly desirable Westwood location. Ideally located in close proximity to the best of what the Westside has to offer. 5 bd 5.5 ba & an ope',
#   '5',
#   '5',
#   'Built-Ins',
#   'bedrooms'],
#  ['1253 GRANVILLE AVE',
#   '16162424',
#   'CLAW',
#   '2016-09-14 00:00:00',
#   '5750.00',
#   'GORGEOUS 4 BED, 3.5 BATH TOWNHOME FOR LEASE! AVAILABLE NOVEMBER 1. THIS UNIT HAS ITS OWN 2-CAR GARAGE W/ DIRECT ACCESS. THE LUXURY MASTER BEDROOM HAS A LOFT, A DUAL WALK-IN CLOSET, FIRE PLACE & LARGE ',
#   '4',
#   '3',
#   'Range Hood',
#   'bedrooms'],
#  ['1012 2ND ST',
#   '16162540',
#   'CLAW',
#   '2016-09-14 00:00:00',
#   '3488000.00',
#   'Unit #1 is "Pending". Just one ocean view townhouse remains available for sale! Coastal contemporary brand new construction- a true labor of love! Direct ocean views from this sleek architectural 3 be',
#   '3',
#   '1',
#   'RangeOven',
#   'bedrooms'],
#  ['1012 2ND ST',
#   '16162570',
#   'CLAW',
#   '2016-09-14 00:00:00',
#   '2895000.00',
#   'Unit #1 is "Pending". Just one ocean view townhouse remains available for sale! Architecturally significant turn-of-the-century Victorian cottage meticulously restored and transformed into a modern ma',
#   '3',
#   '1',
#   'Range Hood',
#   'bedrooms'],
#  ['1203 N SWEETZER AVE',
#   '16162696',
#   'CLAW',
#   '2016-09-15 00:00:00',
#   '499000.00',
#   'Remodeled, spacious and light 1 bedroom and 1 bathroom condo in the coveted West Hollywood complex. Villa Las Brisas. Large open living room and dining area with private balcony. Remodeled eat-in-kitc',
#   '1',
#   '1',
#   'Built-Ins',
#   'bedrooms'],
#  ['810 N TOWNE AVE',
#   '16162826',
#   'CLAW',
#   '2016-09-15 00:00:00',
#   '2300.00',
#   'Impeccable home situated in one of the nicest neighborhood of Claremont. This lovely home has 4 bedrooms, 2 FULL bathrooms. Nice hardwood floors. Kitchen has granite counter tops. Open floor plan. Hug',
#   '4',
#   '2',
#   '',
#   'bedrooms'],
#  ['215 21ST PL',
#   '16163034',
#   'CLAW',
#   '2016-09-15 00:00:00',
#   '4695000.00',
#   'Classic Mediterranean Spanish home designed by J. Charles. Built in 1998 on a 50x152 lot with a guest room above garage. Perfect floor plan- appx 4600sqft with step down living rm, high beamed ceiling',
#   '5',
#   '3',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['3714 FLORESTA WAY',
#   '16163198',
#   'CLAW',
#   '2016-09-16 00:00:00',
#   '849900.00',
#   'Large 2b/2ba with a 3rd Bedroom option. Situated in the highly sought after Historic neighborhood of View Park is this beautiful Cape Cod residence. As you open the Black Onyx front door you are welco',
#   '2',
#   '1',
#   'Built-Ins',
#   'bedrooms'],
#  ['702 MARINE ST',
#   '16163248',
#   'CLAW',
#   '2016-09-16 00:00:00',
#   '1449000.00',
#   'An incredible opportunity to buy an over-sized corner lot just seven blocks from the Ocean. It could be a major fixer or a tear down, you decide. One thing is for sure, this is a prime Santa Monica Oc',
#   '3',
#   '1',
#   '',
#   'bedrooms'],
#  ['21844 PACIFIC COAST HWY',
#   '16163266',
#   'CLAW',
#   '2016-09-16 00:00:00',
#   '10950000.00',
#   'Meticulously remodeled Carbon Beach jewel. This 3 bedroom, 2 bath home with gated entry and beautiful courtyard leads you to the best location on the beach! Relax and unwind in your private hot tub on',
#   '3',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['1301 SEWARD ST',
#   '16163826',
#   'CLAW',
#   '2016-09-22 00:00:00',
#   '3500.00',
#   'Welcome to WEHO! West Hollywood HARD TO FIND pet friendly 2bd/1bath + bungalow. This very bright and charming bungalow is the main house of a detached duplex. Enjoy the serine front yard with privacy ',
#   '2',
#   '1',
#   'RangeOven',
#   'bedrooms'],
#  ['1363 COLTON ST',
#   '16163996',
#   'CLAW',
#   '2016-09-20 00:00:00',
#   '2599000.00',
#   'Located in the S Echo Park / Westlake neighborhood, this double lot offers the opportunity to raise 40 residential units over 2 levels of daylight subterranean, with access off both Colton and Douglas',
#   '0',
#   '',
#   ''],
#  ['11768 ELLICE ST',
#   '16164100',
#   'CLAW',
#   '2016-09-21 00:00:00',
#   '16550000.00',
#   "Oceanfront vistas await at The Spanish Estate, an incomparable residential retreat perched on a private bluff top in Malibu's exclusive Marisol community. Masterfully designed by award-winning archite",
#   '5',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1310 NAPOLI DR',
#   '16164412',
#   'CLAW',
#   '2016-09-21 00:00:00',
#   '6495000.00',
#   'A harmonious union between architecture and nature, this Spanish Villa is set on a half-acre of beautiful land in the desirable Palisades. Originally built in 1923, the home remains true to its Spanis',
#   '4',
#   '3',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1616 N LA BREA AVE',
#   '16164760',
#   'CLAW',
#   '2016-09-22 00:00:00',
#   '3075.00',
#   'NOW OFFERING MOVE IN SPECIALS! This is the last TOP FLOOR CORNER unit! Welcome to The Lofts On La Brea. The newest luxury community. This large studio is perfect for the entertainer that wants the hig',
#   '0',
#   '1',
#   'Microwave',
#   'bathrooms'],
#  ['928 19TH ST',
#   '16164788',
#   'CLAW',
#   '2016-09-22 00:00:00',
#   '6475.00',
#   'Fantastic location! Flexible lease terms- Landlord will consider short, or long term. Just 2 blocks to Montana Avenue shops, cafes and restaurants! Franklin School District! Updated townhouse with 2bd',
#   '2',
#   '2',
#   'Range Hood',
#   'bedrooms'],
#  ['1425 SYCAMORE AVE',
#   '16164958',
#   'CLAW',
#   '2016-10-03 00:00:00',
#   '888000.00',
#   "Located in Northwest Glendale, above Bel Aire Drive, this stylishly remodeled home is sure to delight the most discerning buyer! The gorgeous chef's kitchen is straight out of Restoration Hardware and",
#   '3',
#   '2',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['2445 WALGROVE AVE',
#   '16165062',
#   'CLAW',
#   '2016-09-22 00:00:00',
#   '1235000.00',
#   'Charming 1920s farmhouse on the border of Mar Vista and Venice. This home was originally built in 1925 in La Canada and was moved to the current address in the 1960s. It exudes a vintage ranch-style c',
#   '3',
#   '1',
#   'Range Hood',
#   'bedrooms'],
#  ['18913 ADOLFO AVE',
#   '16165260',
#   'CLAW',
#   '2016-10-04 00:00:00',
#   '865000.00',
#   'Welcome to this wonderful small gated community in the heart of Tarzana. Drive up and you are greeted with a stamped driveway and rose bush lined path leading to a beautiful newer 4 bedroom property. ',
#   '4',
#   '4',
#   'Microwave',
#   'bedrooms'],
#  ['0 Ramera Mountainway',
#   '16165528',
#   'CLAW',
#   '2016-09-26 00:00:00',
#   '3250000.00',
#   'Smashing ocean views from 91 acres in the beautiful Santa Monica Mountains overlooking Malibu and Point Dume. This offering consists of seven contiguous ocean view lots only 2 1/2 miles from Pacific C',
#   '0',
#   '',
#   ''],
#  ['6041 KANAN DUME RD',
#   '16165532',
#   'CLAW',
#   '2016-09-26 00:00:00',
#   '2500000.00',
#   'Amazing land offering of almost six acres within 1/2 mile of Pacific Coast Highway. Surrounded by multi-million dollar homes, the property is one of the few left that are able to accommodate multiple ',
#   '0',
#   '',
#   ''],
#  ['1616 N LA BREA AVE',
#   '16165994',
#   'CLAW',
#   '2016-09-26 00:00:00',
#   '2550.00',
#   'NOW OFFERING MOVE IN SPECIALS! THE BUILDING IS ALMOST SOLD OUT! Welcome to The Lofts On La Brea. The newest luxury community. This large top-floor studio is perfect for the entertainer that wants the ',
#   '0',
#   '1',
#   'Microwave',
#   'bathrooms'],
#  ['1522 AMHERST AVE',
#   '16166222',
#   'CLAW',
#   '2016-09-27 00:00:00',
#   '4350.00',
#   "Beautifully appointed single level condo in a newer Mediterranean courtyard building. A great open floor plan with 3 bedrooms/2.5 bathrooms and filled with natural sunlight. The chef's kitchen has che",
#   '3',
#   '2',
#   'Microwave',
#   'bedrooms'],
#  ['483 CRANE',
#   '16167196',
#   'CLAW',
#   '2016-10-07 00:00:00',
#   '599000.00',
#   'Enchanting 1928 Spanish Bungalow high atop Mt. Washington. Perched above street level on a street-to-street lot, this graceful home has been lovingly preserved and is filled with original detail. Feat',
#   '2',
#   '1',
#   '',
#   'bedrooms'],
#  ['901 TEAKWOOD RD',
#   '16167440',
#   'CLAW',
#   '2016-10-03 00:00:00',
#   '1998000.00',
#   'Mid-Century modern with gorgeous canyon views. This 2,835 sqft home has 4 bed, 3 baths and is bright and spacious throughout with plenty of room for entertaining. The living room with fireplace has la',
#   '4',
#   '3',
#   'Range Hood',
#   'bedrooms'],
#  ['429 MONTANA AVE',
#   '16167460',
#   'CLAW',
#   '2016-10-03 00:00:00',
#   '1498000.00',
#   'Rare opportunity to purchase this wonderful 3 bed, 2 bath penthouse in a high demand Santa Monica area. Near shops, restaurants, Santa Monica Pier, Promenade, Santa Monica stairs and the beach; this h',
#   '3',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['3292 INGLEWOOD',
#   '16167486',
#   'CLAW',
#   '2016-10-29 00:00:00',
#   '7750.00',
#   'If you love the magnificence of a great view, this is one of best. King of the Hill panoramic views of Los Angeles and the the mountains beyond. Dramatic architectural home by Escher Gunewardena, loca',
#   '4',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['1 W CENTURY DR',
#   '16168294',
#   'CLAW',
#   '2016-10-04 00:00:00',
#   '3849000.00',
#   'Live at "The Century" and experience the finest in estate-style living with five-star amenities. The prestigious full-service 42-story high rise was designed by Robert A.M. Stern and features all the ',
#   '2',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['1 W CENTURY DR',
#   '16168406',
#   'CLAW',
#   '2016-10-04 00:00:00',
#   '18500.00',
#   'Live at "The Century" and experience the finest in estate-style living with five-star amenities. The prestigious full-service 42-story high rise was designed by Robert A.M. Stern and features all the ',
#   '2',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['323 ADELAIDE DR',
#   '16168744',
#   'CLAW',
#   '2016-10-06 00:00:00',
#   '6895000.00',
#   'Perfectly situated on the most sought-after block of Adelaide Drive, this luxury four-level Santa Monica canyon home offers an idyllic lifestyle inclusive of breathtaking ocean & canyon views. Nestled',
#   '4',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['2041 N COMMONWEALTH AVE',
#   '16168832',
#   'CLAW',
#   '2016-10-05 00:00:00',
#   '3095.00',
#   'Welcome to 2041 N Commonwealth. Be the the first to live in this Top-floor Corner unit since the full remodel including new floors, fresh paint, new counter tops and new appliances. A large master wit',
#   '2',
#   '1',
#   'Microwave',
#   'bedrooms'],
#  ['2601 PURDUE AVE',
#   '16168984',
#   'CLAW',
#   '2016-10-10 00:00:00',
#   '799000.00',
#   'Westside charmer. Coved ceilings, archways, wood floors, fireplace in a step-down living room. This home has been well maintained and upgraded with central heat and A/C, copper plumbing, CA cellar wit',
#   '2',
#   '1',
#   'Range Hood',
#   'bedrooms'],
#  ['1101 N KENTER AVE',
#   '16169036',
#   'CLAW',
#   '2016-10-06 00:00:00',
#   '1799000.00',
#   'Live above the city of lights in the peaceful and desirable Crestwood Hills area of Brentwood. This 3 bed/4 bath architectural home with wonderful canyon and ocean views boasts an open floor plan and ',
#   '3',
#   '3',
#   'Range Hood',
#   'bedrooms'],
#  ['2765 CASIANO RD',
#   '16169094',
#   'CLAW',
#   '2016-10-06 00:00:00',
#   '2249000.00',
#   'Come embrace a skillful blend of elements that gives this romantic Mediterranean energy and joy. Tour the thoughtful floorpan that will impress. Many incredible features & fine details make it unique.',
#   '5',
#   '4',
#   'Built-Ins',
#   'bedrooms'],
#  ['920 Alta AVE',
#   '16169172',
#   'CLAW',
#   '2016-10-06 00:00:00',
#   '6595000.00',
#   'Architectural oasis located on a quiet corner lot North of Montana- just moments from restaurants & the beach. Steel, wood & glass set the stage for serene living tucked behind privacy walls & hedges.',
#   '6',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['1116 LINDA FLORA DR',
#   '16169260',
#   'CLAW',
#   '2016-10-07 00:00:00',
#   '8499000.00',
#   'Designed by renowned architect Walter Scott Perry in the classic modern Bauhaus tradition, this newly remodeled, 5 bedroom & 6 bathroom contemporary home is sited on a serene, half-acre knoll in Bel A',
#   '5',
#   '3',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['750 S BUNDY DR',
#   '16169676',
#   'CLAW',
#   '2016-10-08 00:00:00',
#   '875000.00',
#   'Located in the heart of Brentwood, minutes from some of the best restaurants, boutiques and farmers markets in Los Angeles, this stylish condo beckons you home. Enjoy a thoughtfully-designed open floo',
#   '2',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['1508 12TH ST',
#   '16170084',
#   'CLAW',
#   '2016-10-13 00:00:00',
#   '779000.00',
#   'ATTENTION INVESTORS looking for an updated easy to manage condo with low dues! Tenant in place until NOV 1st 2017 at $3,300 per month. Can be shown with 48hrs notice. Just 12 blocks from the sand? At ',
#   '2',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['2317 Dickenson Road',
#   '16170236',
#   'CLAW',
#   '2016-10-13 00:00:00',
#   '20000000.00',
#   'An hour outside of Los Angles with country and ocean views of Ojai sits Flying D Ranch. The ultimate ranch - surrounded by a seasonal creek and expansive terrain. Consisting of 1,281 acres and 7 parce',
#   '0',
#   '',
#   ''],
#  ['3181 FEDERAL AVE',
#   '16170260',
#   'CLAW',
#   '2016-10-13 00:00:00',
#   '1589000.00',
#   'Welcome to this Mar Vista/ Westdale Trousdale charmer on a wonderful tree lined street centrally located to everything the neighborhood has to offer.This pristine home offers 4 spacious Bedrooms (2 en',
#   '4',
#   '3',
#   'Microwave',
#   'bedrooms'],
#  ['1125 NAPOLI DR',
#   '16170438',
#   'CLAW',
#   '2016-10-12 00:00:00',
#   '5995000.00',
#   'This rare single story contemporary is a WOW! In the "Coastal Modern" style of its celebrity designer Tim Clarke, interiors include Balinese ceilings, floor to ceiling windows/doors, and a seamless in',
#   '5',
#   '3',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['17795 CALLE DE PALERMO',
#   '16170720',
#   'CLAW',
#   '2016-10-17 00:00:00',
#   '3895000.00',
#   'Welcome home to this beautiful Contemporary Traditional in the exclusive guard gated community of the Palisades Country Estates. This great family home, at the end of a cul-de-sac, offers 5 spacious e',
#   '5',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['235 MAIN ST',
#   '16170802',
#   'CLAW',
#   '2016-10-12 00:00:00',
#   '999000.00',
#   'A spacious expertly designed condominium located on Main Street in Venice. Located in close proximity to Whole Foods, Rose Ave, and Venice Beach. This two bedroom two bath recently updated condo boast',
#   '2',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['15630 WOODVALE RD',
#   '16171376',
#   'CLAW',
#   '2016-10-17 00:00:00',
#   '3499000.00',
#   'Located in the heart of Royal Oaks of Encino, sits a newly remodeled contemporary California craftsmanship 5BD/5.5 BA. This Cape Cod-inspired interior has rich French Oak floors throughout, generous l',
#   '5',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1227 GRANVILLE AVE',
#   '16171784',
#   'CLAW',
#   '2016-11-03 00:00:00',
#   '969000.00',
#   "Spacious two story, top floor condo with 3 bedrooms and 3 bathrooms. Close proximity to the area's best bars and restaurants. Condo has vaulted ceilings, hardwood floors in living room, loft ideal for",
#   '3',
#   '3',
#   'RangeOven',
#   'bedrooms'],
#  ['7462 CLINTON ST',
#   '16171978',
#   'CLAW',
#   '2016-10-17 00:00:00',
#   '825000.00',
#   'Melrose Village Spanish Bungalow Heavy Fixer/Tear-down. Property to be sold in AS-IS condition with no repairs, credits, or warranties. Located in prime 90036 neighborhood moments from The Grove, Melr',
#   '2',
#   '1',
#   '',
#   'bedrooms'],
#  ['610 N Orlando AVE',
#   '16172792',
#   'CLAW',
#   '2016-10-19 00:00:00',
#   '3750.00',
#   'Extensively Remodeled Units for Lease in prime and hip WEHO! Modern designer finishes include French Oak laminate flooring throughout, kitchen with stainless steel appliances, caesartone counters and ',
#   '1',
#   '2',
#   'Microwave',
#   'bedrooms'],
#  ['11166 W SUNSET',
#   '16172810',
#   'CLAW',
#   '2016-10-24 00:00:00',
#   '4495000.00',
#   'A magnificent new gated home beautifully situated on a large lot (over 13,000 feet) at the intersection of Bel-Air and Westwood. Convenient and easy access to Westwood Village, Beverly Hills, Brentwoo',
#   '5',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1102 GALLOWAY ST',
#   '16172836',
#   'CLAW',
#   '2016-11-03 00:00:00',
#   '5985000.00',
#   "A grand union of modern craftsmanship and traditional architecture, this magnificent Cape Cod was conceived by EMMA, the developers responsible for the redesign of Santa Barbara Airport's historic ter",
#   '6',
#   '8',
#   'Built-Ins',
#   'bedrooms'],
#  ['610 N Orlando AVE',
#   '16172880',
#   'CLAW',
#   '2016-10-19 00:00:00',
#   '3750.00',
#   'Extensively Remodeled Units for Lease in prime and hip WEHO! Modern designer finishes include French Oak laminate flooring throughout, a kitchen with stainless steel appliances, caesartone counters an',
#   '2',
#   '2',
#   'Microwave',
#   'bedrooms'],
#  ['11158 OPHIR DR',
#   '16172958',
#   'CLAW',
#   '2016-10-21 00:00:00',
#   '2595000.00',
#   'Gorgeous 3 Bedroom, 3 Bathroom Traditional home exquisitely remodeled! Great flow for entertaining with formal dining & living area, hardwood floors, beautiful moldings, two fireplaces, top of the lin',
#   '3',
#   '3',
#   'RangeOven',
#   'bedrooms'],
#  ['2307 OAKWOOD AVE',
#   '16173026',
#   'CLAW',
#   '2016-10-19 00:00:00',
#   '9250.00',
#   'Eco Chic Living in the heart of Venice! 2,400sq feet single family house on three levels built in 2008. 3 bedrooms, 3.5 baths.Lofty architectural living w volume, light & space. High ceilings, multipl',
#   '3',
#   '4',
#   'Built-Ins',
#   'bedrooms'],
#  ['10267 LELIA LN',
#   '16173052',
#   'CLAW',
#   '2016-10-20 00:00:00',
#   '1495000.00',
#   'Situated at the end of a quiet canyon lane, this stunning contemporary home offers a tranquil, serene setting. Soaring ceilings, expansive windows, and skylights create tremendous natural light throug',
#   '3',
#   '3',
#   '',
#   'bedrooms'],
#  ['3632 VALLEY MEADOW RD',
#   '16173190',
#   'CLAW',
#   '2016-10-20 00:00:00',
#   '1295000.00',
#   'This picturesque mid-century ranch style home on a large quiet lot in coveted Royal Woods is the home you have been waiting for! Open and flowing public areas separated from the private bedroom wing m',
#   '3',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['1024 PALISADES BEACH RD',
#   '16173212',
#   'CLAW',
#   '2016-10-20 00:00:00',
#   '9250000.00',
#   "As part of Santa Monica's historically exclusive Gold Coast, where Hollywood's elite first converged to claim a beachfront oasis to call their own, this John Byers-designed Spanish Colonial Revival el",
#   '5',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['32506 PACIFIC COAST HWY',
#   '16173320',
#   'CLAW',
#   '2016-10-20 00:00:00',
#   '35000.00',
#   'Stunning beach front property! This remodeled home nestled in the Encinal Bluffs, sits right above the sand on a quiet beach cove. This quintessential Tuscan home features authentic finishes of reclai',
#   '3',
#   '3',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['6766 PORTSHEAD RD',
#   '16173342',
#   'CLAW',
#   '2016-10-20 00:00:00',
#   '35000.00',
#   'This magnificent Tuscan home with stunning ocean views sits on over an acre of beautiful landscaped grounds. The property is located in the highly desirable neighborhood of Point Dume with beach keys ',
#   '6',
#   '5',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['525 N N. CRESCENT HEIGHTS',
#   '16173736',
#   'CLAW',
#   '2016-10-21 00:00:00',
#   '3995.00',
#   'Adorable renovated Country English cottage with hardwood floors, two bedrooms, two renovated baths and tons of natural light. Master suite with renovated spa bath with vaulted ceilings and skylight. U',
#   '2',
#   '1',
#   'RangeOven',
#   'bedrooms'],
#  ['450 N SKYEWIAY RD',
#   '16173746',
#   'CLAW',
#   '2016-10-21 00:00:00',
#   '2894000.00',
#   'Tucked away on a serene street North of Sunset in one of the most sought after areas of Brentwood is 450 N. Skyewiay. This immaculate and ample traditional home has been meticulously maintained and ri',
#   '3',
#   '2',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1023 S BUNDY DR',
#   '16173754',
#   'CLAW',
#   '2016-10-21 00:00:00',
#   '2049000.00',
#   'Romantic Spanish Hacienda hidden behind a tall privacy hedge. A true retreat full of old-world charm. 2 bedrooms, 2.5 baths plus a converted garage with office, den and ~ bath. Filled with natural lig',
#   '2',
#   '1',
#   'Built-Ins',
#   'bedrooms'],
#  ['11863 DARLINGTON AVE',
#   '16173864',
#   'CLAW',
#   '2016-10-24 00:00:00',
#   '1195000.00',
#   'You immediately feel at home when you step into this luxurious 2 bedrooms and 2.5 bath condominium with an open floor plan and designer finishes. The living quarters features bamboo floors, crown mold',
#   '2',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['4746 TOLAND WAY',
#   '16174184',
#   'CLAW',
#   '2016-11-02 00:00:00',
#   '768000.00',
#   "Come discover an enchanting brick cottage in the heart of Highland Park. Once you step under the bougainvillea onto the flagstone porch, you'll be smitten. 4746 Toland Way was designed by LA architect",
#   '2',
#   '1',
#   '',
#   'bedrooms'],
#  ['1712 MANZANITA PARK AVE',
#   '16174228',
#   'CLAW',
#   '2016-10-24 00:00:00',
#   '1995000.00',
#   'Step into this beautifully designed home located at the end of a cul-de-sac nestled in the hills of Malibu. This peaceful and private oasis is tucked behind a walled courtyard entry and gated driveway',
#   '4',
#   '2',
#   '',
#   'bedrooms'],
#  ['245 S BURLINGAME AVE',
#   '16174500',
#   'CLAW',
#   '2016-10-25 00:00:00',
#   '7350000.00',
#   'Truly a rare opportunity in Brentwood Park, minutes to the Country Mart, this charming Traditional has great scale and flow -- both indoors and out -- and is ideally suited for gracious living and ent',
#   '5',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['235 OCEAN PARK',
#   '16174642',
#   'CLAW',
#   '2016-10-26 00:00:00',
#   '2079000.00',
#   'Spectacular 3 bed/3 bath + loft townhome located in the heart of Silicon Beach, Just one block from Main Street, and three blocks from the beach! This FAIA Award winning Michael Folonis creation has a',
#   '3',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['18326 CLIFFTOP WAY',
#   '16174714',
#   'CLAW',
#   '2016-10-25 00:00:00',
#   '16000.00',
#   'Panoramic ocean views from this stunning, modern architectural home designed to perfection! Gorgeous open floor plan with high ceilings and skylights. The grand living room features walls of glass wit',
#   '3',
#   '2',
#   'Microwave',
#   'bedrooms'],
#  ['11730 CHENAULT ST',
#   '16174844',
#   'CLAW',
#   '2016-11-10 00:00:00',
#   '3295000.00',
#   'Located in a highly desirable Brentwood location, this delightful Traditional home is filled with charm and character. Flooded with natural light, this home boasts three en-suite bedrooms upstairs, in',
#   '4',
#   '4',
#   'Built-Ins',
#   'bedrooms'],
#  ['701 N ALPINE DR',
#   '16174878',
#   'CLAW',
#   '2016-10-27 00:00:00',
#   '7995000.00',
#   "Elegantly situated in the heart of Beverly Hills sits this 2 story Mediterranean home w/ architectural details, 5 bdrms, 6 ~ bas & an inviting GH w/ add'l bedrm & bath. Enter thru the dramatic 2 story",
#   '5',
#   '5',
#   'Built-Ins',
#   'bedrooms'],
#  ['5625 W CRESCENT PARK',
#   '16175522',
#   'CLAW',
#   '2016-10-29 00:00:00',
#   '799000.00',
#   'Elegant contemporary two bedroom condo at the much sought after Metro in Playa Vista. Located on the 3rd floor, this unit has been impeccably maintained and was recently upgraded. Step into the formal',
#   '2',
#   '2',
#   'Range Hood',
#   'bedrooms'],
#  ['609 11TH ST',
#   '16175808',
#   'CLAW',
#   '2016-10-28 00:00:00',
#   '3195000.00',
#   'Charming original Spanish style 3 bedroom + 1.75 bath single level home. Approximately 2,266 sq ft on a 50~150 lot with pool and converted garage. Tons of natural light, hardwood floors and original d',
#   '3',
#   '1',
#   'Built-Ins',
#   'bedrooms'],
#  ['7463 ROSEWOOD AVE',
#   '16175946',
#   'CLAW',
#   '2016-10-31 00:00:00',
#   '899000.00',
#   'Beautifully renovated character Spanish Bungalow in amazing Melrose Village (90036) location. Living room w/ barreled ceilings, formal dining room, newer hardwood floors, wood burning fireplace, newer',
#   '2',
#   '1',
#   'Microwave',
#   'bedrooms'],
#  ['610 N Orlando AVE',
#   '16176498',
#   'CLAW',
#   '2016-11-01 00:00:00',
#   '3550.00',
#   'Extensively Remodeled Units for Lease in prime and hip WeHo! Modern designer finishes include French Oak laminate wood flooring throughout, a kitchen complete with stainless steel appliances, Caesarst',
#   '2',
#   '2',
#   'Microwave',
#   'bedrooms'],
#  ['11435 BIONA DR',
#   '16177116',
#   'CLAW',
#   '2016-11-03 00:00:00',
#   '1368000.00',
#   'Beautiful Four Bedroom + Studio home. Located on a Corner Lot. Warm & inviting spacious living room filled w/ character touches such as peg & groove hardwood floors, wood beam ceiling and decorative f',
#   '4',
#   '1',
#   'Oven',
#   'bedrooms'],
#  ['849 S BROADWAY',
#   '16177234',
#   'CLAW',
#   '2016-11-04 00:00:00',
#   '2649000.00',
#   'From the unprecedented Penthouse Collection of actor, producer, musician and real estate investor Johnny Depp comes this two story, 2 bedroom/3 bath residence featuring 2,400 square feet of vibrantly-',
#   '2',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['849 S BROADWAY',
#   '16177260',
#   'CLAW',
#   '2016-11-04 00:00:00',
#   '2750000.00',
#   "From the unprecedented Penthouse Collection of actor, producer, musician and real estate investor Johnny Depp comes this two story, 2 bedroom/3 bath residence situated within Los Angeles's most archit",
#   '2',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['849 S BROADWAY',
#   '16177272',
#   'CLAW',
#   '2016-11-04 00:00:00',
#   '1999000.00',
#   'From the unprecedented Penthouse Collection of actor, producer, musician and real estate investor Johnny Depp comes this two story, 1 bedroom/2 bath residence sitting atop the landmark Eastern Columbi',
#   '1',
#   '1',
#   'Built-Ins',
#   'bedrooms'],
#  ['3850 GLENALBYN DR',
#   '16177332',
#   'CLAW',
#   '2016-11-03 00:00:00',
#   '650000.00',
#   'Impeccable home!!! Tons of upgrades!!! Remodeled kitchen with stainless steel appliances and granite counter tops. 2-car attached garage. Zoning is possible for backyard expansion. Lots of possibiliti',
#   '3',
#   '2',
#   'Microwave',
#   'bedrooms'],
#  ['11017 WAGNER ST',
#   '16177368',
#   'CLAW',
#   '2016-11-03 00:00:00',
#   '1285000.00',
#   'Sensational home in the coveted Vets Park neighborhood. A true move-in ready, opportunity. Meticulously maintained. Features include, oak flooring, large master suite, bright kitchen with breakfast no',
#   '2',
#   '1',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['849 S BROADWAY',
#   '16177590',
#   'CLAW',
#   '2016-11-04 00:00:00',
#   '1565000.00',
#   "This two bedroom residence located in Downtown L.A.'s landmark Eastern Columbia Building has been completely reimagined by designer/architect Andrea Keller, drawing its design inspiration from Havana,",
#   '2',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['1290 OAKWOOD DR',
#   '16178020',
#   'CLAW',
#   '2016-11-11 00:00:00',
#   '1188000.00',
#   'Come away to this enchanting cottage in an idyllic, creekside setting to escape the city hustle and relax. Verdant green lawns surround you as you stroll up the stone path to this two bedroom, two bat',
#   '2',
#   '1',
#   'Range Hood',
#   'bedrooms'],
#  ['1730 CAMINO PALMERO ST',
#   '16178144',
#   'CLAW',
#   '2016-11-07 00:00:00',
#   '395000.00',
# ...
#   'Built-In Electric',
#   'bedrooms'],
#  ['21552 Yucatan Avenue',
#   '316007842',
#   'ITECH',
#   '2016-08-19 00:00:00',
#   '799000.00',
#   'Beautifully remodeled five bedroom, three bath home located south of the Blvd. This home exemplifies an ideal open floorplan, soaring ceilings & an abundance of natural light. Features include a cooks',
#   '5',
#   '2',
#   'Gas',
#   'bedrooms'],
#  ['3138 Cloudcrest Road',
#   '316007976',
#   'ITECH',
#   '2016-08-24 00:00:00',
#   '850000.00',
#   "Peace, calm and quiet in the hills of La Crescenta, this Traditional-Contemporary home offers what you've been waiting for. Within the last two years this three bedroom,/two bathroom home has been ext",
#   '3',
#   '2',
#   '',
#   'bedrooms'],
#  ['2388 North Altadena Drive',
#   '316008372',
#   'ITECH',
#   '2016-09-06 00:00:00',
#   '1790000.00',
#   'House Re-Imagined! It is incredible what can be done for $50K. Come and see the transformation. Canopies of Oaks shelter this one-of-a-kind Rustic Craftsman residence that rests on the banks of Eaton ',
#   '6',
#   '5',
#   'Free Standing Gas',
#   'bedrooms'],
#  ['2329 Lake View Avenue',
#   '316008538',
#   'ITECH',
#   '2016-09-09 00:00:00',
#   '1349000.00',
#   'Designed by noted Architect, Steven Hill, this stunning example of contemporary modernism is bound to impress you. Perched on an expansive ridge in Silverlake Heights, this 2,100 Sf contemporary home ',
#   '3',
#   '2',
#   'Built-In Gas',
#   'bedrooms'],
#  ['1990 Hilldale Drive',
#   '316008853',
#   'ITECH',
#   '2016-09-19 00:00:00',
#   '899000.00',
#   'Charming hilltop home! Built in 1941, this 3 bedroom 2 bathroom traditional 2 level home has been meticulously maintained by the current owners for the past 25 years and is described as having good bo',
#   '3',
#   '1',
#   '',
#   'bedrooms'],
#  ['1124 East Chestnut Street #39',
#   '316008990',
#   'ITECH',
#   '2016-09-28 00:00:00',
#   '2400.00',
#   'Charming townhouse style condo. Spacious, beautifully maintained light filled two bedroom two bath unit with hardwood floors, fireplace, two balconies, in unit washer/dryer and private two car garage.',
#   '2',
#   '2',
#   'Free Standing Gas',
#   'bedrooms'],
#  ['2454 Oswego Street #201',
#   '316009006',
#   'ITECH',
#   '2016-09-25 00:00:00',
#   '728000.00',
#   'Architectural excellence and modern finishes combine seamlessly in this luxurious single level rear unit. Built in 2007, the complex boasts idyllic qualities like lush foliage and curved paver-lined p',
#   '3',
#   '3',
#   'Free Standing Gas',
#   'bedrooms'],
#  ['2011 Hall Canyon Drive',
#   '316009078',
#   'ITECH',
#   '2016-09-26 00:00:00',
#   '3695000.00',
#   'This timeless contemporary Craftsman residence in La Canada, built by C.H. Anderson, was once a grove of deodar pines, transformed into a property fit for entertaining and movement. Renowned architect',
#   '4',
#   '2',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['247 Crystal Lane',
#   '316009157',
#   'ITECH',
#   '2016-09-28 00:00:00',
#   '575000.00',
#   'Beautiful remodeled single family residence at the end of a cul-de-sac. The stunning large kitchen is truly a show stopper with dark custom cabinets including a wine rack, stone counter tops, recessed',
#   '3',
#   '1',
#   'Built-In Gas',
#   'bedrooms'],
#  ['901 South Flower Street #506',
#   '316009232',
#   'ITECH',
#   '2016-09-29 13:35:23',
#   '2650.00',
#   'Situated in the vibrant downtown LA South Park area is this live/work light-filled one bedroom gem. It features open floor plan, modern built-in appliances, European cabinets, enclosed bedroom, ample ',
#   '1',
#   '1',
#   '',
#   'bedrooms'],
#  ['4842 Alminar Avenue',
#   '316009342',
#   'ITECH',
#   '2016-10-03 00:00:00',
#   '1339000.00',
#   'Welcome to 4842 Alminar Ave., considered a prime location for many in La Canada! Alminar is a quaint tree lined street not far from schools, shopping and restaurants. This cozy and charming 3 bedroom,',
#   '3',
#   '2',
#   'Cooktop - Gas',
#   'bedrooms'],
#  ['8258 Owens Street',
#   '316009344',
#   'ITECH',
#   '2016-10-04 00:00:00',
#   '549000.00',
#   'Charming traditional home on a nice tree lined street in Sunland. Built in 1953, this 3 bedroom 2 bathroom home has been well maintained and has many recent upgrades including wide plank hardwood floo',
#   '3',
#   '1',
#   '',
#   'bedrooms'],
#  ['4762 La Canada Boulevard',
#   '316009356',
#   'ITECH',
#   '2016-10-07 00:00:00',
#   '2195000.00',
#   'This stunning 1926 Spanish estate sits on nearly 24,000 square feet of flat land and features a detached 1-BR/1-BA GUEST HOUSE. This house combines original character details with a fantastic floor pl',
#   '4',
#   '2',
#   'Cooktop - Gas',
#   'bedrooms'],
#  ['4113 Lanterman Lane',
#   '316009368',
#   'ITECH',
#   '2016-10-03 00:00:00',
#   '1195000.00',
#   'Beautiful turn-key traditional in La Canada Flintridge. Fantastic floor plan for entertaining with great indoor-outdoor flow. Large living room/ dining room, cooks kitchen and breakfast nook open to t',
#   '4',
#   '1',
#   '',
#   'bedrooms'],
#  ['1436 Valane Drive',
#   '316009501',
#   'ITECH',
#   '2016-10-07 00:00:00',
#   '799000.00',
#   'A dog-leg left from the first fairway of the Oakmont Country Club is where you will find this hidden, quaint street with friendly neighbors. This single-story, mid Century home has clean lines that ar',
#   '2',
#   '1',
#   '',
#   'bedrooms'],
#  ['526 Venado Vista Drive',
#   '316009646',
#   'ITECH',
#   '2016-10-12 00:00:00',
#   '1195000.00',
#   'This 1957 ranch home is located on a quiet cul-de-sac near Paradise Canyon Elementary School and hiking trails. The home offers a large living/great room with high ceilings, fireplace, built-in cabine',
#   '3',
#   '2',
#   '',
#   'bedrooms'],
#  ['1320 Loreto Drive',
#   '316009693',
#   'ITECH',
#   '2016-10-14 00:00:00',
#   '1126000.00',
#   'Price Reduction! Beautiful 1926 Character Spanish! Located on a peaceful street, this lovely Spanish Colonial is immaculate. Living Room Offers Gleaming Tongue and Groove Hardwood floors and the state',
#   '3',
#   '2',
#   'Built-Ins',
#   'bedrooms'],
#  ['4439 Alta Canyada Road',
#   '316009737',
#   'ITECH',
#   '2016-10-15 16:59:01',
#   '4000.00',
#   'Charming 3 BR/ 3 BA home FOR LEASE in the award-winning La Canada Unified School district. The updated kitchen features granite counters and opens to the family room and dining area. Spacious Master B',
#   '3',
#   '1',
#   '',
#   'bedrooms'],
#  ['330 Cordova Street #312',
#   '316009746',
#   'ITECH',
#   '2016-10-17 00:00:00',
#   '599000.00',
#   'Just One and half blocks (5 minute walk) from the Metro Gold Line, this heavily-treed urban oasis is conveniently located near restaurants, shopping, art galleries, Old Pasadena, Paseo, South Lake Ave',
#   '2',
#   '2',
#   'Gas',
#   'bedrooms'],
#  ['385 South Oakland Avenue #105',
#   '316009753',
#   'ITECH',
#   '2016-10-19 00:00:00',
#   '355000.00',
#   'Chic studio located on a wonderful tree-lined street in the heart of Pasadena. Well situated in the sophisticated Oakland Towers, this unit features a double door entry, large picture windows with vie',
#   '0',
#   '1',
#   'RangeOven',
#   'bathrooms'],
#  ['5715 Summit Crest Drive',
#   '316009802',
#   'ITECH',
#   '2016-10-18 00:00:00',
#   '1450000.00',
#   'Beautiful property in desirable La Canada/Flintridge. Charming traditional one story house in a beautiful neighborhood, kitchen with breakfast room and convenient and spacious family room, Banquet siz',
#   '3',
#   '1',
#   'Gas/Electric Range',
#   'bedrooms'],
#  ['277 Atchison Street',
#   '316009844',
#   'ITECH',
#   '2016-10-19 21:51:45',
#   '3500.00',
#   'Charming home located on a tree lined street. Great curb appeal, mature trees, backyard porch, hardwood floors, living room with a fireplace, nicely remodeled bathrooms, and kitchen, lots of closet sp',
#   '4',
#   '2',
#   '',
#   'bedrooms'],
#  ['705 East Palm Avenue',
#   '316009913',
#   'ITECH',
#   '2016-10-21 00:00:00',
#   '598000.00',
#   "1940's Traditional in desirable NE Monrovia neighborhood within Gold Ribbon School boundry. This 2 bedroom 1 bath home features an open concept living room dining room w/hardwood floors and playroom t",
#   '2',
#   '1',
#   '',
#   'bedrooms'],
#  ['1143 Crowne Drive',
#   '316009971',
#   'ITECH',
#   '2016-11-02 00:00:00',
#   '3000.00',
#   'Light-filled 3 bedroom, 2 bath Townhome that feels like a single family residence in great Rose Court neighborhood. This Craftsman style home features beautifully redone hardwood floors in the main li',
#   '3',
#   '2',
#   'Free Standing Gas',
#   'bedrooms'],
#  ['2331 North Orchard Drive',
#   '316010002',
#   'ITECH',
#   '2016-10-25 00:00:00',
#   '899000.00',
#   'Welcome Home! This beautiful home offers 3 bedrooms, 2 baths with 2004 sq ft of living space. Enjoy gathering in your living room by one of the fireplaces that is connected to the spacious dining area',
#   '3',
#   '1',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['1710 East Mendocino Street',
#   '316010040',
#   'ITECH',
#   '2016-10-26 00:00:00',
#   '899000.00',
#   'Nestled in the scenic foothills of the San Gabriel Mountains, this beautifully maintained mid-century ranch is a composition of large, light-filled spacesa generous canvas to make your own. The 9,520-',
#   '3',
#   '1',
#   '',
#   'bedrooms'],
#  ['1121 Hillcroft Road',
#   '316010077',
#   'ITECH',
#   '2016-10-27 12:33:34',
#   '1895000.00',
#   'This sensational 1927 Spanish Colonial, revived to perfection, stands proudest among the other notable properties in this most coveted location of Rossmoyne Historic District. Rossmoyne is one of Glen',
#   '4',
#   '4',
#   '',
#   'bedrooms'],
#  ['370 South Berkeley Avenue',
#   '316010117',
#   'ITECH',
#   '2016-10-28 00:00:00',
#   '1699000.00',
#   'Nothing defines Southern California real estate like the understated elegance of a two-story Spanish Revival home. Located in the prestigious Cal Tech area of Pasadena, with San Marino just a block aw',
#   '4',
#   '1',
#   '',
#   'bedrooms'],
#  ['929 Old Mill Road',
#   '316010138',
#   'ITECH',
#   '2016-11-01 00:00:00',
#   '1998000.00',
#   'This modern contemporary home resides on a corner lot in the upscale Langham Area of Pasadena, a neighborhood characterized by rolling, oak-covered terrain on the base of the picturesque San Gabriel M',
#   '3',
#   '3',
#   'Built-In Gas',
#   'bedrooms'],
#  ['3263 Orlando Road',
#   '316010184',
#   'ITECH',
#   '2016-10-31 00:00:00',
#   '3950.00',
#   'San Marino Schools! Located in a quiet cul de sac, this traditional single story ranch home has 4 bedrooms and 3.5 bath including permitted guest house ( approx.545 sqft) in San Marino school district',
#   '4',
#   '3',
#   '',
#   'bedrooms'],
#  ['555 Sierra Madre Boulevard',
#   '316010241',
#   'ITECH',
#   '2016-11-02 11:55:26',
#   '2485000.00',
#   'Located in the desirable city of San Marino, near the prestigious Huntington Library, perched up and set back from the street, is this 4 bedrooms 4 baths whimsical traditional. It has been extensively',
#   '4',
#   '1',
#   'Free Standing Gas',
#   'bedrooms'],
#  ['265 West California Boulevard #8',
#   '316010261',
#   'ITECH',
#   '2016-11-03 07:20:11',
#   '608000.00',
#   'Fantastic three bedroom townhome located in Cal Ritz-Park complex across from Singer Park. Conveniently located close to Old Town, Rose Parade route, Huntington Hospital. This unit is bright and light',
#   '3',
#   '1',
#   'Cooktop - Gas',
#   'bedrooms'],
#  ['0 Roselawn',
#   '316010267',
#   'ITECH',
#   '2016-11-03 00:00:00',
#   '150000.00',
#   'Great Opportunity! Buyer needs to check with City of Glendale and LA County Flood Control for possible specific uses of this property. Plans drawn in 2005 are available for viewing.',
#   '0',
#   '',
#   ''],
#  ['766 Elmira Street',
#   '316010316',
#   'ITECH',
#   '2016-11-05 06:16:15',
#   '540000.00',
#   'Charming, updated (approx 4 years ago) Spanish-style single family framed by lovely landscaping. Truly move-in ready. Centrally located, close to shopping, with easy freeway access. The remodeled kitc',
#   '3',
#   '1',
#   'Built-In Gas',
#   'bedrooms'],
#  ['560 Chaparral Court',
#   '316010376',
#   'ITECH',
#   '2016-11-07 00:00:00',
#   '5000.00',
#   'Set against the backdrop of the majestic San Gabriel Mountains, this beautiful single-level Spainsh home rests behind the gates of La Vina in Altadena. Enter through the lush courtyard to the front do',
#   '3',
#   '3',
#   'Built-In Gas',
#   'bedrooms'],
#  ['391 West Harriet Street',
#   '316010426',
#   'ITECH',
#   '2016-11-10 00:00:00',
#   '650000.00',
#   'Wonderful traditional 3 bedrooms, 2 bathrooms home located in Altadena. Granite counter-tops in the kitchen and baths, newer cabinets throughout. Light and bright living room with fireplace, formal di',
#   '3',
#   '2',
#   'RangeOven',
#   'bedrooms'],
#  ['2079 Skyview Drive',
#   '316010451',
#   'ITECH',
#   '2016-11-09 00:00:00',
#   '2175000.00',
#   "A dramatic backdrop of the San Gabriel Mountains and mature scenery frames the magnificent setting for this superb Mediterranean revival located in Altadena's premier estate area. Home to a celebrity ",
#   '5',
#   '5',
#   '',
#   'bedrooms'],
#  ['3301 Vickers Drive',
#   '316010501',
#   'ITECH',
#   '2016-11-11 00:00:00',
#   '1150000.00',
#   'Beautiful one owner home in prime Montecito Park location. This single story residence features 4 bedrooms, 2.5 baths. New wood flooring throughout most of the house. Spacious master suite with ample ',
#   '4',
#   '1',
#   '',
#   'bedrooms'],
#  ['27815 Zion Court',
#   '316010528',
#   'ITECH',
#   '2016-11-13 00:00:00',
#   '569900.00',
#   'Beautiful Hillcrest home for sale with 4 bedrooms (1 downstairs) and 3 baths. Upon entering you will be greeted with a beautiful living room with high ceilings along with dining area. Enjoy entertaini',
#   '4',
#   '3',
#   'Oven',
#   'bedrooms'],
#  ['5042 Indianola Way',
#   '316010536',
#   'ITECH',
#   '2016-11-14 00:00:00',
#   '2600000.00',
#   '5042 Indianola Way is a one of a kind property, located on a desirable cul-de-sac in La Canada Flintridge, close to Paradise Canyon Elementary and town. This handsome single story traditional home fea',
#   '5',
#   '4',
#   'Built-In BBQ',
#   'bedrooms'],
#  ['574 Garfield Avenue',
#   '316010634',
#   'ITECH',
#   '2016-11-18 00:00:00',
#   '785000.00',
#   'Located in the prestigious and desirable Franciscan Woods. This tri-level townhouse is exceptional in every aspect. The newly built front deck is ideal for relaxing and entertaining with amazing views',
#   '2',
#   '3',
#   'Built-Ins',
#   'bedrooms'],
#  ['20280 Allentown Drive',
#   '316010650',
#   'ITECH',
#   '2016-11-17 00:00:00',
#   '1299000.00',
#   'Nestled on a breathtaking secluded lot in the esteemed Vista De Oro neighborhood, this completely re-imagined mid-century home marries pristine contemporary features with luxury amenities that wash aw',
#   '4',
#   '3',
#   'Built-In Gas',
#   'bedrooms'],
#  ['545 Westgate Street',
#   '316010702',
#   'ITECH',
#   '2016-11-18 07:45:06',
#   '1025000.00',
#   'ALARM IS ON.Two-story Victorian home with an inviting wraparound porch and lots of character throughout and many nice upgrades including copper plumbing, updated electrical and central air. Large livi',
#   '4',
#   '1',
#   'Built-In Gas',
#   'bedrooms'],
#  ['30810 Broad Beach Road',
#   'PT2979',
#   'partnerstrust',
#   '2014-07-24 16:33:10',
#   '50000.00',
#   '<p>This Chic Cape Cod home with guest house is located on the sand with a private grassy yard, open terrace, built-in spa, barbeque area, fire pit and access to beach. Wonderful accommodations for gue',
#   '4',
#   '4',
#   '',
#   'bedrooms'],
#  ['0 Encinal Canyon',
#   'PT3446',
#   'partnerstrust',
#   '2015-02-13 14:29:51',
#   '999990.00',
#   '<p>Extraordinarily beautiful pastoral acreage with amazing ocean and Catalina views. It is rare to find this much useable land in the Santa Monica mountains in a setting that only Encinal Canyon can p',
#   '0',
#   '',
#   ''],
#  ['13320 Beach Avenue #307',
#   'PT3481',
#   'partnerstrust',
#   '2015-02-27 09:00:55',
#   '3700.00',
#   '<p>Location, location, location! Fabulous loft w over 1200 square ft of living space. This loft has top quality brand name fixtures &amp; appliances, w careful attention paid to quality, detailing &am',
#   '0',
#   '2',
#   ''],
#  ['1110 Felbar Avenue',
#   'SB16712658MR',
#   'CRMLS',
#   '2016-10-04 00:00:00',
#   '779000.00',
#   'A decorator perfect home in Torrance Gardens awaits: enter this 1,611 sq. ft. gem from a welcoming brick front porch, step into the inviting living room with beautiful wood floors, and take your time ',
#   '3',
#   '2',
#   'RangeOven',
#   'bedrooms']]

# %%
df = pd.DataFrame(columns=header, data=data)
df.head()
# Out:
#                StreetAddress     MlsId MlsName           DateListed  \
# 0  0 Castro Peak Mountainway  14799273    CLAW  2014-10-03 00:00:00
# 1           0 SADDLE PEAK RD  14802845    CLAW  2014-10-17 00:00:00
# 2    21310 PACIFIC COAST HWY  15883387    CLAW  2015-03-03 00:00:00
# 3            23826 MALIBU RD  15888095    CLAW  2015-03-18 00:00:00
# 4                943 16th ST  15959941    CLAW  2015-11-18 00:00:00
#
#        Price                                        Description Bedrooms  \
# 0  535000.00  Enjoy amazing ocean and island views from this...        0
# 1  200000.00  Spectacular views from this 4+ acre property p...        0
# 2   23500.00  A STUNNING Architectural beautifully designed ...        3
# 3   72500.00  July & August not available. "Captured in Para...        5
# 4  230000.00  Due to an overwhelming response we are no long...        2
#
#   FullBathrooms Appliances RoomCount
# 0                               None
# 1                               None
# 2             4  Built-Ins  bedrooms
# 3             4  Built-Ins  bedrooms
# 4             1  RangeOven  bedrooms

# %% [markdown]
# ## Creating mask for finding "and" in the description

# %%
and_mask = df['Description'].str.contains('and')
df = df[and_mask]

# %% [markdown]
# ## Creating a mask for isolating only 2016 dates and sorted by date

# %%
## formatting to DateTime
df['DateListed'] = pd.to_datetime(df['DateListed'])

# %%
#add a new column for Year.
df['Year'] = df['DateListed'].apply(lambda x: x.year)
#add a new column for Month.
df['Month'] = df['DateListed'].apply(lambda x: x.month)
#add a new column for Day.
df['Day'] = df['DateListed'].apply(lambda x: x.day)

# %%
year_mask = df['Year'] == 2016
df = df[year_mask]

# %%
#sortby to get the DataFrame aligned by Date
df.sort_values(['Year', 'Month', 'Day'], ascending=True, inplace=True)
df.drop(['Year', 'Month', 'Day'], axis=1, inplace=True)
df
# Out:
#                         StreetAddress      MlsId MlsName          DateListed  \
# 157             828 BALLARD CANYON RD   16968013    CLAW 2016-01-07 00:00:00
# 159                  6692 WILDLIFE RD   16970871    CLAW 2016-01-20 00:00:00
# 161                845 Highland Drive  316000525   ITECH 2016-02-04 00:00:00
# 6         27086 MALIBU COVE COLONY DR   16106762    CLAW 2016-03-16 00:00:00
# 7                       36 BREEZE AVE   16109128    CLAW 2016-03-25 00:00:00
# 8                31652 BROAD BEACH RD   16114818    CLAW 2016-04-12 00:00:00
# 10                 11258 Laurie Drive   16115640    CLAW 2016-04-14 00:00:00
# 11                    28011 PAQUET PL   16118008    CLAW 2016-04-25 00:00:00
# 15            32036 PACIFIC COAST HWY   16130744    CLAW 2016-06-02 00:00:00
# 16                   888 Blackmore DR   16132084    CLAW 2016-06-05 00:00:00
# 21            24808 Woolsey Canyon RD   16134756    CLAW 2016-06-14 00:00:00
# 23               7350 PACIFIC VIEW DR   16135516    CLAW 2016-06-16 00:00:00
# 25                 1422 SAN YSIDRO DR   16137056    CLAW 2016-06-22 00:00:00
# 163         64 North Arroyo Boulevard  316005809   ITECH 2016-06-22 00:00:00
# 164                899 Winston Avenue  316005875   ITECH 2016-06-22 00:00:00
# 26                     6225 GAYTON PL   16137086    CLAW 2016-06-24 00:00:00
# 28                  2317 Dickenson RD   16142180    CLAW 2016-07-11 00:00:00
# 165                  1401 Via Del Rey  316006132   ITECH 2016-07-15 00:00:00
# 29                    514 LILLIAN WAY   16142204    CLAW 2016-07-21 00:00:00
# 31             602 PALISADES BEACH RD   16145020    CLAW 2016-07-21 00:00:00
# 32                   4906 MENDOTA AVE   16146358    CLAW 2016-07-22 00:00:00
# 34                     29220 WAGON RD   16148546    CLAW 2016-07-29 00:00:00
# 168           5215 Vista Miguel Drive  316007195   ITECH 2016-07-29 00:00:00
# 37        27112 MALIBU COVE COLONY DR   16150318    CLAW 2016-08-05 00:00:00
# 38                    181 SURFVIEW DR   16150758    CLAW 2016-08-05 00:00:00
# 39                  4960 VANALDEN AVE   16151208    CLAW 2016-08-11 00:00:00
# 41                     7135 HOLLYWOOD   16153228    CLAW 2016-08-15 00:00:00
# 171                  82 Monterey Lane  316007701   ITECH 2016-08-15 11:31:13
# 42                    9640 SIERRA HWY   16154748    CLAW 2016-08-22 00:00:00
# 45                  24014 PARK CASINO   16155556    CLAW 2016-08-22 00:00:00
# ..                                ...        ...     ...                 ...
# 124                   4746 TOLAND WAY   16174184    CLAW 2016-11-02 00:00:00
# 202        555 Sierra Madre Boulevard  316010241   ITECH 2016-11-02 11:55:26
# 107                1227 GRANVILLE AVE   16171784    CLAW 2016-11-03 00:00:00
# 111                  1102 GALLOWAY ST   16172836    CLAW 2016-11-03 00:00:00
# 135                    11435 BIONA DR   16177116    CLAW 2016-11-03 00:00:00
# 139                 3850 GLENALBYN DR   16177332    CLAW 2016-11-03 00:00:00
# 203  265 West California Boulevard #8  316010261   ITECH 2016-11-03 07:20:11
# 204                        0 Roselawn  316010267   ITECH 2016-11-03 00:00:00
# 136                    849 S BROADWAY   16177234    CLAW 2016-11-04 00:00:00
# 137                    849 S BROADWAY   16177260    CLAW 2016-11-04 00:00:00
# 138                    849 S BROADWAY   16177272    CLAW 2016-11-04 00:00:00
# 141                    849 S BROADWAY   16177590    CLAW 2016-11-04 00:00:00
# 205                 766 Elmira Street  316010316   ITECH 2016-11-05 06:16:15
# 146                       255 MAIN ST   16178870    CLAW 2016-11-09 00:00:00
# 208                2079 Skyview Drive  316010451   ITECH 2016-11-09 00:00:00
# 129                 11730 CHENAULT ST   16174844    CLAW 2016-11-10 00:00:00
# 207           391 West Harriet Street  316010426   ITECH 2016-11-10 00:00:00
# 142                   1290 OAKWOOD DR   16178020    CLAW 2016-11-11 00:00:00
# 145                     1 EASTWIND ST   16178844    CLAW 2016-11-11 00:00:00
# 147                   942 VENEZIA AVE   16178966    CLAW 2016-11-11 00:00:00
# 149              330 S BARRINGTON AVE   16179426    CLAW 2016-11-11 00:00:00
# 150                    5340 DENNY AVE   16179532    CLAW 2016-11-11 00:00:00
# 151                     5625 CASE AVE   16179540    CLAW 2016-11-11 00:00:00
# 210                  27815 Zion Court  316010528   ITECH 2016-11-13 00:00:00
# 152                  2919 GRAYSON AVE   16179602    CLAW 2016-11-14 00:00:00
# 211                5042 Indianola Way  316010536   ITECH 2016-11-14 00:00:00
# 155              4714 LA VILLA MARINA   16181224    CLAW 2016-11-18 00:00:00
# 156              33583 MULHOLLAND HWY   16181228    CLAW 2016-11-18 00:00:00
# 212               574 Garfield Avenue  316010634   ITECH 2016-11-18 00:00:00
# 214               545 Westgate Street  316010702   ITECH 2016-11-18 07:45:06
#
#            Price                                        Description Bedrooms  \
# 157   2879000.00  Meticulously maintained historic 5-acre horse ...        4
# 159     45000.00  New Construction Point Dume Rental with covete...        5
# 161   4699999.00  Unbelievable custom home in the hills of La Ca...        6
# 6       25000.00  Gorgeous oceanfront home with views to Point D...        3
# 7        6500.00  his designer, custom architectural remodel on ...        2
# 8     5800000.00  Welcome to an oasis over looking the Pacific O...        3
# 10     798000.00  NEW PROJECT - SHOVEL READY. *NOTE* This projec...        0
# 11    6995000.00  Beautiful estate with panoramic ocean views lo...        5
# 15    2450000.00  Build your Malibu dream home! Flat lot on almo...        0
# 16    2888000.00  This approx: 59 ACRE DEVELOPMENT SITE consists...        0
# 21    1298000.00  RESIDENTIAL DEVELOPMENT SITE: Consisting of 10...        0
# 23    2195000.00  Perched above a cul-de-sac in the Hollywood Hi...        3
# 25    2035000.00  Location,location,location. Located on one of ...        2
# 163    919000.00  Meticulously maintained light-filled townhouse...        4
# 164   2700000.00  Located on a quiet street in the desirable San...        4
# 26    3195000.00  This beautiful 4 bedroom/4.5 bath is situated ...        4
# 28   20000000.00  An hour outside of Los Angles with country and...        3
# 165   1988000.00  Mid Century 1970's iconic Charles Wong designe...        6
# 29    1399000.00  MOTIVATED SELLER! BRING US AN OFFER!! Perfectl...        3
# 31   10500000.00  Incredible opportunity to own this classic Fre...        7
# 32     468300.00  Amazing investor opportunity in hot, hot Highl...        2
# 34    2688000.00  Perched atop a secluded promontory, this inspi...        6
# 168   1848000.00  Quintessential Cape Cod style home located in ...        4
# 37      20000.00  This sleek and sexy beach house is located on ...        3
# 38      10815.00  Spectacular Contemporary with dramatic and arc...        4
# 39    3495000.00  Designed by noted architect Gus Duffy and situ...        7
# 41     650000.00  Hollywood Versailles Towers at it's best! Come...        1
# 171    879000.00  Quaint Sierra Madre Traditional corner lot hom...        3
# 42   12800000.00  Just 35 miles outside of Los Angeles, Agua Dul...        5
# 45    1719500.00  Gorgeous home with view of Calabasas golf cour...        4
# ..           ...                                                ...      ...
# 124    768000.00  Come discover an enchanting brick cottage in t...        2
# 202   2485000.00  Located in the desirable city of San Marino, n...        4
# 107    969000.00  Spacious two story, top floor condo with 3 bed...        3
# 111   5985000.00  A grand union of modern craftsmanship and trad...        6
# 135   1368000.00  Beautiful Four Bedroom + Studio home. Located ...        4
# 139    650000.00  Impeccable home!!! Tons of upgrades!!! Remodel...        3
# 203    608000.00  Fantastic three bedroom townhome located in Ca...        3
# 204    150000.00  Great Opportunity! Buyer needs to check with C...        0
# 136   2649000.00  From the unprecedented Penthouse Collection of...        2
# 137   2750000.00  From the unprecedented Penthouse Collection of...        2
# 138   1999000.00  From the unprecedented Penthouse Collection of...        1
# 141   1565000.00  This two bedroom residence located in Downtown...        2
# 205    540000.00  Charming, updated (approx 4 years ago) Spanish...        3
# 146      6495.00  One of a kind 2 bedroom, 2 bath modern penthou...        2
# 208   2175000.00  A dramatic backdrop of the San Gabriel Mountai...        5
# 129   3295000.00  Located in a highly desirable Brentwood locati...        4
# 207    650000.00  Wonderful traditional 3 bedrooms, 2 bathrooms ...        3
# 142   1188000.00  Come away to this enchanting cottage in an idy...        2
# 145   3695000.00  Rising tall over a rare stretch of soft sand i...        3
# 147   1795000.00  Impeccably updated Spanish Modern in the heart...        2
# 149    749000.00  2+2 beautifully updated condo, located on the ...        2
# 150   1100000.00  Approved 8-Unit construction project in the No...        0
# 151   1650000.00  Bring your Developers! This property is perfec...        0
# 210    569900.00  Beautiful Hillcrest home for sale with 4 bedro...        4
# 152   3986000.00  Embodying the relaxed casual elegance and priv...        3
# 211   2600000.00  5042 Indianola Way is a one of a kind property...        5
# 155    839000.00  Exquisitely renovated multilevel mid century t...        2
# 156   7488000.00  Set to awe-inspiring ocean views and soaring s...        4
# 212    785000.00  Located in the prestigious and desirable Franc...        2
# 214   1025000.00  ALARM IS ON.Two-story Victorian home with an i...        4
#
#     FullBathrooms         Appliances RoomCount
# 157             4         Range Hood  bedrooms
# 159             6       Built-In BBQ  bedrooms
# 161             3          RangeOven  bedrooms
# 6               3          Built-Ins  bedrooms
# 7               1          Built-Ins  bedrooms
# 8               3          Built-Ins  bedrooms
# 10                                        None
# 11              4       Built-In BBQ  bedrooms
# 15                                        None
# 16                                        None
# 21                                        None
# 23              3          Built-Ins  bedrooms
# 25              2         Range Hood  bedrooms
# 163             2                     bedrooms
# 164             3        Double Oven  bedrooms
# 26              4       Built-In BBQ  bedrooms
# 28              2       Built-In BBQ  bedrooms
# 165             4          Built-Ins  bedrooms
# 29              1       Built-In Gas  bedrooms
# 31              7                     bedrooms
# 32              1                     bedrooms
# 34              5       Built-In BBQ  bedrooms
# 168             3                     bedrooms
# 37              3         Range Hood  bedrooms
# 38              3          Built-Ins  bedrooms
# 39              4       Built-In BBQ  bedrooms
# 41              2          Built-Ins  bedrooms
# 171             1  Built-In Electric  bedrooms
# 42              4          RangeOven  bedrooms
# 45              3       Built-In BBQ  bedrooms
# ..            ...                ...       ...
# 124             1                     bedrooms
# 202             1  Free Standing Gas  bedrooms
# 107             3          RangeOven  bedrooms
# 111             8          Built-Ins  bedrooms
# 135             1               Oven  bedrooms
# 139             2          Microwave  bedrooms
# 203             1      Cooktop - Gas  bedrooms
# 204                                       None
# 136             2          Built-Ins  bedrooms
# 137             2          Built-Ins  bedrooms
# 138             1          Built-Ins  bedrooms
# 141             2          Built-Ins  bedrooms
# 205             1       Built-In Gas  bedrooms
# 146             2          Built-Ins  bedrooms
# 208             5                     bedrooms
# 129             4          Built-Ins  bedrooms
# 207             2          RangeOven  bedrooms
# 142             1         Range Hood  bedrooms
# 145             2          Built-Ins  bedrooms
# 147             2          Built-Ins  bedrooms
# 149             2          Built-Ins  bedrooms
# 150                                       None
# 151                                       None
# 210             3               Oven  bedrooms
# 152             1       Built-In BBQ  bedrooms
# 211             4       Built-In BBQ  bedrooms
# 155             2          Built-Ins  bedrooms
# 156             4       Built-In BBQ  bedrooms
# 212             3          Built-Ins  bedrooms
# 214             1       Built-In Gas  bedrooms
#
# [142 rows x 10 columns]

# %%
df.to_csv('final.csv')
